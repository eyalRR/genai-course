# %% [markdown]
# # Solution to Beginner Exercise:

# %%
# Solution to Beginner Exercise:

import base64
from openai import OpenAI

client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4o-audio-preview",
    modalities=["text", "audio"],
    audio={"voice": "alloy", "format": "wav"},
    messages=[
        {
            "role": "user",
            "content": "What is the weather like today?"
        }
    ]
)

print(completion.choices[0])

wav_bytes = base64.b64decode(completion.choices[0].message.audio.data)

with open("../audio/weather.wav", "wb") as f:
    f.write(wav_bytes)
# Out:
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=ChatCompletionAudio(id='audio_679e8951fda081909a38a7ca64981461', data='...', expires_at=1738446689, transcript="I don't have real-time weather information, so I'm unable to provide the current weather conditions. You can check a weather app or website for today's forecast."), function_call=None, tool_calls=None))
